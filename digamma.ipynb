# %%
# %matplotlib inline

# %%
import sympy
from sympy import Function, log, exp, integrate, pi, symbols, simplify
from sympy.functions.special.gamma_functions import digamma, gamma
from sympy.plotting import plot
from mpmath import euler

# %%
x = symbols('x')
F = Function('F')
f = digamma(-1/x)

# %%
plot(f, (x, 1.77, 5))

# %%
plot(f, (x, -10, -1e-5))

# %%
plot(f, (x, -100, -10))

# %%
[(i, v, v / i) for i in xrange(2,25) for v in [f.evalf(subs={x: i})]]
# Out:
# [(2, 0.0364899739785765, 0.0182449869892883),
#  (3, 1.68176558421341, 0.560588528071137),
#  (4, 2.91413912021353, 0.728534780053382),
#  (5, 4.03499143329386, 0.806998286658772),
#  (6, 5.10927058732774, 0.851545097887957),
#  (7, 6.15960412226933, 0.879943446038475),
#  (8, 7.19598292845230, 0.899497866056538),
#  (9, 8.22351159973065, 0.913723511081184),
#  (10, 9.24507305005295, 0.924507305005295),
#  (11, 10.2624195881253, 0.932947235284115),
#  (12, 11.2766780714547, 0.939723172621229),
#  (13, 12.2886062737546, 0.945277405673434),
#  (14, 13.2987326407137, 0.949909474336696),
#  (15, 14.3074369834300, 0.953829132228665),
#  (16, 15.3149993255043, 0.957187457844019),
#  (17, 16.3216306673012, 0.960095921605956),
#  (18, 17.3274930259043, 0.962638501439129),
#  (19, 18.3327128741073, 0.964879624953014),
#  (20, 19.3373903837947, 0.966869519189734),
#  (21, 20.3416059266767, 0.968647901270317),
#  (22, 21.3454247372703, 0.970246578966831),
#  (23, 22.3489003171027, 0.971691318134899),
#  (24, 23.3520769595879, 0.973003206649498)]

# %%
f.evalf(subs={x:1e+15}) / 1e+15
# Out:
# 0.999999678735254

# %%
plot(f, (x, -3, -0.5))

# %%
digamma(1)
# Out:
# -EulerGamma

# %%
digamma(1).evalf()
# Out:
# -0.577215664901533

# %%
f.evalf(subs={x:-1})
# Out:
# -0.577215664901533

# %%
gamma(1)
# Out:
# 1

# %%
[[y, y.diff(), simplify(y.diff(x)/y), simplify(log(y).diff(x))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, x**(-2), -1/x, -1/x],
#  [1/(-x + 1), (-x + 1)**(-2), -1/(x - 1), -1/(x - 1)],
#  [x/(-x + 1), x/(-x + 1)**2 + 1/(-x + 1), -1/(x*(x - 1)), -1/(x*(x - 1))],
#  [1 - 1/x, x**(-2), 1/(x*(x - 1)), 1/(x*(x - 1))]]

# %%
[[y, simplify(exp(1j*pi + integrate(log(y).diff(x), x)))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, -1/x],
#  [1/(-x + 1), -1/(x - 1)],
#  [x/(-x + 1), -x/(x - 1)],
#  [1 - 1/x, -(x - 1)/x]]

# %%
[[y, exp(integrate(simplify(log(1/(1-y)).diff(x)), x))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, x/(x + 1)],
#  [1/(-x + 1), (x - 1)/x],
#  [x/(-x + 1), (x - 1)/(x - 1/2)],
#  [1 - 1/x, x]]

# %%
log(-1).evalf()
# Out:
# 3.14159265358979*I

# %%
[[y, simplify(exp(log(-1) + integrate(log(y).diff(x), x)))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, -1/x],
#  [1/(-x + 1), -1/(x - 1)],
#  [x/(-x + 1), -x/(x - 1)],
#  [1 - 1/x, (-x + 1)/x]]

# %%
exp(integrate(simplify(log(integrate(F(-1/x), x)).diff(x)), x))
# Out:
# exp(Integral(F(-1/x)/Integral(F(-1/x), x), x))

# %%
h = simplify(f - x + euler)

# %%
plot(h, (x, -1e7, -1e5))

# %%
plot(h, (x, 1e5, 1e7))

# %%
[(i, v, v - i + euler) for i in xrange(2,25) for v in [f.evalf(subs={x: i})]]
# Out:
# [(2, 0.0364899739785765, -1.38629436111989),
#  (3, 1.68176558421341, -0.741018750885056),
#  (4, 2.91413912021353, -0.508645214884940),
#  (5, 4.03499143329386, -0.387792901804605),
#  (6, 5.10927058732774, -0.313513747770728),
#  (7, 6.15960412226933, -0.263180212829140),
#  (8, 7.19598292845230, -0.226801406646163),
#  (9, 8.22351159973065, -0.199272735367814),
#  (10, 9.24507305005295, -0.177711285045519),
#  (11, 10.2624195881253, -0.160364746973196),
#  (12, 11.2766780714547, -0.146106263643719),
#  (13, 12.2886062737546, -0.134178061343824),
#  (14, 13.2987326407137, -0.124051694384721),
#  (15, 14.3074369834300, -0.115347351668485),
#  (16, 15.3149993255043, -0.107785009594164),
#  (17, 16.3216306673012, -0.101153667797221),
#  (18, 17.3274930259043, -0.0952913091941533),
#  (19, 18.3327128741073, -0.0900714609912051),
#  (20, 19.3373903837947, -0.0853939513037937),
#  (21, 20.3416059266767, -0.0811784084218069),
#  (22, 21.3454247372703, -0.0773595978281748),
#  (23, 22.3489003171027, -0.0738840179957955),
#  (24, 23.3520769595879, -0.0707073755105200)]
