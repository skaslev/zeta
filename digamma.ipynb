# %%
# %matplotlib inline

# %%
import sympy
from sympy import log, exp, integrate, EulerGamma, pi, symbols, Function, simplify
from sympy.functions.special.gamma_functions import digamma, gamma
from sympy.plotting import plot

# %%
x = symbols('x')
F = Function('F')
f = digamma(-1/x) + EulerGamma.evalf() # - digamma(1).evalf()

# %%
plot(f, (x, 1.77, 5))

# %%
plot(f, (x, -10, -1e-5))

# %%
plot(f, (x, -100, -10))

# %%
[(i, v, v2,  v - v2) for i in xrange(2,25) for v, v2 in [(f.evalf(subs={x: i}), f.evalf(subs={x: i/(1.0-i)}))]]
# Out:
# [(2, 0.613705638880109, -1.38629436111989, 2.00000000000000),
#  (3, 2.25898124911494, -0.741018750885056, 3.00000000000000),
#  (4, 3.49135478511506, -0.508645214884939, 4.00000000000000),
#  (5, 4.61220709819539, -0.387792901804606, 5.00000000000000),
#  (6, 5.68648625222927, -0.313513747770728, 6.00000000000000),
#  (7, 6.73681978717086, -0.263180212829140, 7.00000000000000),
#  (8, 7.77319859335384, -0.226801406646162, 8.00000000000000),
#  (9, 8.80072726463218, -0.199272735367815, 9.00000000000000),
#  (10, 9.82228871495448, -0.177711285045519, 10.0000000000000),
#  (11, 10.8396352530268, -0.160364746973197, 11.0000000000000),
#  (12, 11.8538937363563, -0.146106263643719, 12.0000000000000),
#  (13, 12.8658219386562, -0.134178061343823, 13.0000000000000),
#  (14, 13.8759483056153, -0.124051694384721, 14.0000000000000),
#  (15, 14.8846526483315, -0.115347351668485, 15.0000000000000),
#  (16, 15.8922149904058, -0.107785009594165, 16.0000000000000),
#  (17, 16.8988463322028, -0.101153667797221, 17.0000000000000),
#  (18, 17.9047086908058, -0.0952913091941544, 18.0000000000000),
#  (19, 18.9099285390088, -0.0900714609912065, 19.0000000000000),
#  (20, 19.9146060486962, -0.0853939513037924, 20.0000000000000),
#  (21, 20.9188215915782, -0.0811784084218070, 21.0000000000000),
#  (22, 21.9226404021718, -0.0773595978281745, 22.0000000000000),
#  (23, 22.9261159820042, -0.0738840179957958, 23.0000000000000),
#  (24, 23.9292926244895, -0.0707073755105217, 24.0000000000000)]

# %%
f.evalf(subs={x:1e+15}) / 1e+15
# Out:
# 0.999999996372506

# %%
plot(f, (x, -3, -0.5))

# %%
digamma(1)
# Out:
# -EulerGamma

# %%
digamma(1).evalf()
# Out:
# -0.577215664901533

# %%
f.evalf(subs={x:-1})
# Out:
# 4.94291515243064e-18

# %%
gamma(1)
# Out:
# 1

# %%
[[y, y.diff(), simplify(y.diff(x)/y), simplify(log(y).diff(x))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, x**(-2), -1/x, -1/x],
#  [1/(-x + 1), (-x + 1)**(-2), -1/(x - 1), -1/(x - 1)],
#  [x/(-x + 1), x/(-x + 1)**2 + 1/(-x + 1), -1/(x*(x - 1)), -1/(x*(x - 1))],
#  [1 - 1/x, x**(-2), 1/(x*(x - 1)), 1/(x*(x - 1))]]

# %%
[[y, simplify(exp(1j*pi + integrate(log(y).diff(x), x)))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, -1/x],
#  [1/(-x + 1), -1/(x - 1)],
#  [x/(-x + 1), -x/(x - 1)],
#  [1 - 1/x, -(x - 1)/x]]

# %%
[[y, exp(integrate(simplify(log(1/(1-y)).diff(x)), x))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, x/(x + 1)],
#  [1/(-x + 1), (x - 1)/x],
#  [x/(-x + 1), (x - 1)/(x - 1/2)],
#  [1 - 1/x, x]]

# %%
log(-1).evalf()
# Out:
# 3.14159265358979*I

# %%
[[y, simplify(exp(log(-1) + integrate(log(y).diff(x), x)))] for y in [-1/x, 1/(1-x), x/(1-x), 1-1/x]]
# Out:
# [[-1/x, -1/x],
#  [1/(-x + 1), -1/(x - 1)],
#  [x/(-x + 1), -x/(x - 1)],
#  [1 - 1/x, (-x + 1)/x]]

# %%
exp(integrate(simplify(log(integrate(F(-1/x), x)).diff(x)), x))
# Out:
# exp(Integral(F(-1/x)/Integral(F(-1/x), x), x))

# %%
h = simplify(f - x)

# %%
plot(h, (x, -1e7, -1e5))

# %%
plot(h, (x, 1e5, 1e7))

# %%
[(i, v, v - i) for i in xrange(int(1e6),int(1e6+25)) for v in [f.evalf(subs={x: i})]]
# Out:
# [(1000000, 999999.999998355, -1.64494849741459e-6),
#  (1000001, 1000000.99999836, -1.64494849741459e-6),
#  (1000002, 1000001.99999836, -1.64494849741459e-6),
#  (1000003, 1000002.99999836, -1.64494849741459e-6),
#  (1000004, 1000003.99999836, -1.64494849741459e-6),
#  (1000005, 1000004.99999836, -1.64494849741459e-6),
#  (1000006, 1000005.99999836, -1.64494849741459e-6),
#  (1000007, 1000006.99999836, -1.64494849741459e-6),
#  (1000008, 1000007.99999836, -1.64494849741459e-6),
#  (1000009, 1000008.99999836, -1.64494849741459e-6),
#  (1000010, 1000009.99999836, -1.64494849741459e-6),
#  (1000011, 1000010.99999836, -1.64494849741459e-6),
#  (1000012, 1000011.99999836, -1.64494849741459e-6),
#  (1000013, 1000012.99999836, -1.64494849741459e-6),
#  (1000014, 1000013.99999836, -1.64494849741459e-6),
#  (1000015, 1000014.99999836, -1.64494849741459e-6),
#  (1000016, 1000015.99999836, -1.64494849741459e-6),
#  (1000017, 1000016.99999836, -1.64494849741459e-6),
#  (1000018, 1000017.99999836, -1.64494849741459e-6),
#  (1000019, 1000018.99999836, -1.64494849741459e-6),
#  (1000020, 1000019.99999836, -1.64494849741459e-6),
#  (1000021, 1000020.99999836, -1.64494849741459e-6),
#  (1000022, 1000021.99999836, -1.64494849741459e-6),
#  (1000023, 1000022.99999836, -1.64494849741459e-6),
#  (1000024, 1000023.99999836, -1.64494849741459e-6)]

# %%
f.subs(x, 2)
# Out:
# -2*log(2) - EulerGamma + 2.57721566490153

# %%
f.subs(x, 2).evalf()
# Out:
# 0.613705638880109

# %%
[[i, f.subs(x, i)] for i in xrange(10)]
# Out:
# [[0, polygamma(0, zoo) + 0.577215664901533],
#  [1, zoo],
#  [2, -2*log(2) - EulerGamma + 2.57721566490153],
#  [3, -3*log(3)/2 - EulerGamma + sqrt(3)*pi/6 + 3.57721566490153],
#  [4, -3*log(2) - EulerGamma + pi/2 + 4.57721566490153],
#  [5, 0.577215664901533 + polygamma(0, -1/5)],
#  [6, 0.577215664901533 + polygamma(0, -1/6)],
#  [7, 0.577215664901533 + polygamma(0, -1/7)],
#  [8, 0.577215664901533 + polygamma(0, -1/8)],
#  [9, 0.577215664901533 + polygamma(0, -1/9)]]

# %%
[[i, f.subs(x, i)] for i in xrange(0,-10,-1)]
# Out:
# [[0, polygamma(0, zoo) + 0.577215664901533],
#  [-1, -EulerGamma + 0.577215664901533],
#  [-2, -2*log(2) - EulerGamma + 0.577215664901533],
#  [-3, -3*log(3)/2 - sqrt(3)*pi/6 - EulerGamma + 0.577215664901533],
#  [-4, -3*log(2) - pi/2 - EulerGamma + 0.577215664901533],
#  [-5, polygamma(0, 1/5) + 0.577215664901533],
#  [-6, polygamma(0, 1/6) + 0.577215664901533],
#  [-7, polygamma(0, 1/7) + 0.577215664901533],
#  [-8, polygamma(0, 1/8) + 0.577215664901533],
#  [-9, polygamma(0, 1/9) + 0.577215664901533]]

# %%
[[i, v, simplify(v - i - log(4) - f.subs(x, i/(1-i))).evalf()] for i in xrange(int(1e6),int(1e6+25)) for v in [f.evalf(subs={x: i})]]
# Out:
# [[1000000, 999999.999998355, -1.64494849741953e-6],
#  [1000001, 1000000.99999836, -1.64494849741953e-6],
#  [1000002, 1000001.99999836, -1.64494849741953e-6],
#  [1000003, 1000002.99999836, -1.64494849741953e-6],
#  [1000004, 1000003.99999836, -1.64494849741953e-6],
#  [1000005, 1000004.99999836, -1.64494849741953e-6],
#  [1000006, 1000005.99999836, -1.64494849741953e-6],
#  [1000007, 1000006.99999836, -1.64494849741953e-6],
#  [1000008, 1000007.99999836, -1.64494849741953e-6],
#  [1000009, 1000008.99999836, -1.64494849741953e-6],
#  [1000010, 1000009.99999836, -1.64494849741953e-6],
#  [1000011, 1000010.99999836, -1.64494849741953e-6],
#  [1000012, 1000011.99999836, -1.64494849741953e-6],
#  [1000013, 1000012.99999836, -1.64494849741953e-6],
#  [1000014, 1000013.99999836, -1.64494849741953e-6],
#  [1000015, 1000014.99999836, -1.64494849741953e-6],
#  [1000016, 1000015.99999836, -1.64494849741953e-6],
#  [1000017, 1000016.99999836, -1.64494849741953e-6],
#  [1000018, 1000017.99999836, -1.64494849741953e-6],
#  [1000019, 1000018.99999836, -1.64494849741953e-6],
#  [1000020, 1000019.99999836, -1.64494849741953e-6],
#  [1000021, 1000020.99999836, -1.64494849741953e-6],
#  [1000022, 1000021.99999836, -1.64494849741953e-6],
#  [1000023, 1000022.99999836, -1.64494849741953e-6],
#  [1000024, 1000023.99999836, -1.64494849741953e-6]]

# %%
log(4).evalf()
# Out:
# 1.38629436111989

# %%
log(2).evalf()
# Out:
# 0.693147180559945

# %%
plot(f-x, (x, 1e5, 1e7))

# %%
plot(f.subs(x, x/(1-x)), (x, 1e5, 1e7))

# %%
plot(f-x-f.subs(x, x/(1-x)), (x, 1e5, 1e7))

# %%
EulerGamma.evalf()
# Out:
# 0.577215664901533

# %%
plot(f-x-f.subs(x, x/(1-x)), (x, 1.1, 9))

# %%
plot(f-f.subs(x, x/(1-x)), (x, 1.1, 9))

# %%
plot(f-f.subs(x, x/(1-x)), (x, -9, 9))
